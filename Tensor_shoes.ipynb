# %% [markdown]
# <a href="https://colab.research.google.com/github/Joonw00/tensor_game/blob/main/Tensor_shoes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import pandas as pd

# %%
신발 = pd.read_csv("/content/shoe.csv")
print(신발.columns)
신발.head()
# Out:
# Index(['스타포스', '추옵', '주스텟퍼', '아랫잠', '가격'], dtype='object')
#    스타포스   추옵  주스텟퍼  아랫잠    가격
# 0    17  110    15  1.0  12.0
# 1    17  110    21  1.0  25.0
# 2    18  104    15  2.0  24.0
# 3    18  111    15  1.5  16.5
# 4    17  109    15  1.3  13.5

# %%
독립 = 신발[['스타포스', '추옵', '주스텟퍼', '아랫잠']]
종속 = 신발[['가격']]
print(독립.shape, 종속.shape)
# Out:
# (48, 4) (48, 1)

# %%
X = tf.keras.layers.Input(shape=[4])
H = tf.keras.layers.Dense(4, activation='swish')(X)
H = tf.keras.layers.Dense(4, activation='swish')(X)
Y = tf.keras.layers.Dense(1)(H)
model = tf.keras.models.Model(X,Y)
model.compile(loss='mse')

# %%
model.fit(독립, 종속, epochs=200, verbose = 2)
# Out:
# Epoch 1/200
# 2/2 - 0s - loss: 15.8252 - 25ms/epoch - 13ms/step
# Epoch 2/200
# 2/2 - 0s - loss: 15.4594 - 11ms/epoch - 5ms/step
# Epoch 3/200
# 2/2 - 0s - loss: 15.3764 - 19ms/epoch - 10ms/step
# Epoch 4/200
# 2/2 - 0s - loss: 15.3638 - 6ms/epoch - 3ms/step
# Epoch 5/200
# 2/2 - 0s - loss: 15.6104 - 14ms/epoch - 7ms/step
# Epoch 6/200
# 2/2 - 0s - loss: 15.5769 - 15ms/epoch - 7ms/step
# Epoch 7/200
# 2/2 - 0s - loss: 15.5566 - 8ms/epoch - 4ms/step
# Epoch 8/200
# 2/2 - 0s - loss: 15.3737 - 16ms/epoch - 8ms/step
# Epoch 9/200
# 2/2 - 0s - loss: 15.4898 - 8ms/epoch - 4ms/step
# Epoch 10/200
# 2/2 - 0s - loss: 15.7370 - 8ms/epoch - 4ms/step
# Epoch 11/200
# 2/2 - 0s - loss: 15.9576 - 10ms/epoch - 5ms/step
# Epoch 12/200
# 2/2 - 0s - loss: 15.5984 - 8ms/epoch - 4ms/step
# Epoch 13/200
# 2/2 - 0s - loss: 15.5517 - 10ms/epoch - 5ms/step
# Epoch 14/200
# 2/2 - 0s - loss: 15.3647 - 12ms/epoch - 6ms/step
# Epoch 15/200
# 2/2 - 0s - loss: 15.7934 - 22ms/epoch - 11ms/step
# Epoch 16/200
# ...

# %%
print(model.predict(독립[0:10]))
print(종속[0:10])
# Out:
# [[14.549331]
#  [24.14958 ]
#  [19.621689]
#  [16.670734]
#  [16.626354]
#  [20.202072]
#  [26.709991]
#  [26.8853  ]
#  [24.259329]
#  [14.549331]]
#      가격
# 0  12.0
# 1  25.0
# 2  24.0
# 3  16.5
# 4  13.5
# 5  22.0
# 6  26.0
# 7  33.5
# 8  28.0
# 9  11.0
